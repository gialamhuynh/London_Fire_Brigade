# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the excel file
df_i = pd.read_excel("https://data.london.gov.uk/download/london-fire-brigade-incident-records/f5066d66-c7a3-415f-9629-026fbda61822/LFB%20Incident%20data%20from%202018%20onwards.xlsx", header=0)

# %%
# Filter the DataFrame to include only rows where CalYear is 2023
df_i = df_i[df_i['CalYear'] == 2023]

# Randomly select 10,000 rows from the filtered DataFrame
df_i = df_i.sample(n=10000, random_state=23)

# Define the directory path to save the DataFrame
directory = '../data/raw/'

# Save the sampled DataFrame as a CSV file in the specified directory
df_i.to_csv(directory + 'df_i.csv', index=False)

# Get info about DF
print(df_i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 647602 to 662756
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IncidentNumber                          10000 non-null  object
#  1   DateOfCall                              10000 non-null  datetime64[ns]
#  2   CalYear                                 10000 non-null  int64
#  3   TimeOfCall                              10000 non-null  object
#  4   HourOfCall                              10000 non-null  int64
#  5   IncidentGroup                           10000 non-null  object
#  6   StopCodeDescription                     10000 non-null  object
#  7   SpecialServiceType                      3731 non-null   object
#  8   PropertyCategory                        10000 non-null  object
#  9   PropertyType                            10000 non-null  object
# ...

# %%
# Display the first and last 10 rows
print(df_i.head(10))
print(df_i.tail(10))

# Print the data types of each column to check the data type of 'CalYear'
print(df_i.dtypes)

# Filter the DataFrame to include only rows where CalYear is 2023
df_i = df_i[df_i['CalYear'] == 2023]

# Randomly select 10,000 rows from the filtered DataFrame
df_i = df_i.sample(n=10000, random_state=23)

# Define the directory path to save the DataFrame
directory = '../data/raw/'

# Save the sampled DataFrame as a CSV file in the specified directory
df_i.to_csv(directory + 'df_i.csv', index=False)

# Get info about DF
print(df_i.info())
# Out:
#          IncidentNumber DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 569195  038967-19032023 2023-03-19     2023   14:11:51          14
# 553324  013803-28012023 2023-01-28     2023   12:51:59          12
# 610311  108007-19072023 2023-07-19     2023   10:28:50          10
# 574425  047316-05042023 2023-04-05     2023   15:51:54          15
# 625855  133862-02092023 2023-09-02     2023   10:22:12          10
# 579981  056533-24042023 2023-04-24     2023   08:36:37           8
# 615018  115770-01082023 2023-08-01     2023   19:54:29          19
# 590172  073337-25052023 2023-05-25     2023   13:01:04          13
# 579648  055974-22042023 2023-04-22     2023   23:33:34          23
# 617645  120055-09082023 2023-08-09     2023   16:20:49          16
#
#           IncidentGroup        StopCodeDescription  \
# 569195      False Alarm  False alarm - Good intent
# 553324  Special Service            Special Service
# 610311  Special Service            Special Service
# ...

# %%
# Filter the DataFrame to include only rows where CalYear is 2023
df_i = df_i[df_i['CalYear'] == 2023]

# Randomly select 10,000 rows from the filtered DataFrame
df_i = df_i.sample(n=10000, random_state=23)

# Define the directory path to save the DataFrame
directory = '../data/raw/'

# Save the sampled DataFrame as a CSV file in the specified directory
df_i.to_csv(directory + 'df_i.csv', index=False)

# %%
# Display the first few rows of the sampled DataFrame
print(df_i.head(10))

# Get info about DF
print(df_i.info())
# Out:
#          IncidentNumber DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 569195  038967-19032023 2023-03-19     2023   14:11:51          14
# 553324  013803-28012023 2023-01-28     2023   12:51:59          12
# 610311  108007-19072023 2023-07-19     2023   10:28:50          10
# 574425  047316-05042023 2023-04-05     2023   15:51:54          15
# 625855  133862-02092023 2023-09-02     2023   10:22:12          10
# 579981  056533-24042023 2023-04-24     2023   08:36:37           8
# 615018  115770-01082023 2023-08-01     2023   19:54:29          19
# 590172  073337-25052023 2023-05-25     2023   13:01:04          13
# 579648  055974-22042023 2023-04-22     2023   23:33:34          23
# 617645  120055-09082023 2023-08-09     2023   16:20:49          16
#
#           IncidentGroup        StopCodeDescription  \
# 569195      False Alarm  False alarm - Good intent
# 553324  Special Service            Special Service
# 610311  Special Service            Special Service
# ...
